# %%
# %matplotlib notebook

# %%
import matplotlib as mpl

mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(2, 3, 'x')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = x

plt.figure()
plt.scatter(x, y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import numpy as np
linear = np.array([1, 2, 3, 4, 5, 6, 7, 8])
quad = linear**2

plt.figure()
plt.plot(linear, '-o', quad, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<matplotlib.lines.Line2D at 0x24bf1084f60>,
#  <matplotlib.lines.Line2D at 0x24bf108b0f0>]

# %%
plt.gca().fill_between(range(len(linear)), linear, quad, facecolor='green', alpha=0.5)
